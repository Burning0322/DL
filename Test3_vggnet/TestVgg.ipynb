# %%
# !rm -rf /content/DL
# !GIT_LFS_SKIP_SMUDGE=1 git clone https://github.com/Burning0322/DL.git
# Out:
# Cloning into 'DL'...
# remote: Enumerating objects: 7636, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 7636 (delta 79), reused 50 (delta 22), pack-reused 7496 (from 1)
# Receiving objects: 100% (7636/7636), 221.73 MiB | 43.79 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Updating files: 100% (14718/14718), done.

# %%
# %cd /content/DL/Test3_vggnet
# !ls
# Out:
# /content/DL/Test3_vggnet
# '~$Record.xlsx'       flower_data   predict.py	  train.py
#  class_indices.json   model.py	    Record.xlsx

# %%
# !python train.py
# Out:
# 2025-10-01 01:10:20.638078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759281020.657682     404 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759281020.664924     404 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759281020.688612     404 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from google.colab import runtime
# 训练完成后断开运行时（Colab 会话会自动关闭 GPU）
runtime.unassign()
